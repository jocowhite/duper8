# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data_noturning1 = np.genfromtxt('data/data_noturning1.csv', delimiter=',')
data_noturning2 = np.genfromtxt('data/data_noturning2.csv', delimiter=',')
data_noturning3 = np.genfromtxt('data/data_noturning3.csv', delimiter=',')
data_turning = np.genfromtxt('data/data_turning.csv', delimiter=',')
data_turning2 = np.genfromtxt('data/data_turning2.csv', delimiter=',')

all_data_noturning = np.stack((data_noturning1, data_noturning2, data_noturning3), axis=-1)

#plt.plot(data_noturning1)

fig, ax = plt.subplots()
ax.plot(data_turning, label='turning')
ax.plot(all_data_noturning, label='no turning')
leg = ax.legend()
